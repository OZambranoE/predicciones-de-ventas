# %% [markdown]
# <a href="https://colab.research.google.com/github/OZambranoE/predicciones-de-ventas/blob/main/prediccion_tsunamisW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
filename = "/content/drive/MyDrive/Codificación de Dojo/SemanaM2/earthquake_data.csv"
df = pd.read_csv(filename)
df.head(20)
# Out:
#                                             title  magnitude  \
# 0    M 7.0 - 18 km SW of Malango, Solomon Islands        7.0
# 1        M 6.9 - 204 km SW of Bengkulu, Indonesia        6.9
# 2                                        M 7.0 -         7.0
# 3             M 7.3 - 205 km ESE of Neiafu, Tonga        7.3
# 4                                        M 6.6 -         6.6
# 5               M 7.0 - south of the Fiji Islands        7.0
# 6               M 6.8 - south of the Fiji Islands        6.8
# 7         M 6.7 - 60 km SSW of Boca Chica, Panama        6.7
# 8          M 6.8 - 55 km SSW of Aguililla, Mexico        6.8
# 9          M 7.6 - 35 km SSW of Aguililla, Mexico        7.6
# 10              M 6.9 - 90 km E of Yujing, Taiwan        6.9
# 11               M 6.5 - 96 km SE of Lugu, Taiwan        6.5
# 12         M 7.0 - 209 km SSE of Isangel, Vanuatu        7.0
# 13  M 7.6 - 70 km E of Kainantu, Papua New Guinea        7.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      782 non-null    object
#  1   magnitude  782 non-null    float64
#  2   date_time  782 non-null    object
#  3   cdi        782 non-null    int64
#  4   mmi        782 non-null    int64
#  5   alert      415 non-null    object
#  6   tsunami    782 non-null    int64
#  7   sig        782 non-null    int64
#  8   net        782 non-null    object
#  9   nst        782 non-null    int64
#  10  dmin       782 non-null    float64
#  11  gap        782 non-null    float64
#  12  magType    782 non-null    object
#  13  depth      782 non-null    float64
#  14  latitude   782 non-null    float64
#  15  longitude  782 non-null    float64
#  16  location   777 non-null    object
#  17  continent  206 non-null    object
#  18  country    484 non-null    object
# ...

# %%
#se crea un nuevo df con las columnas a utilizar
df_filtrado = df[["magnitude","depth","sig", "gap", "tsunami"]]
df_filtrado.head(10)
# Out:
#    magnitude    depth   sig   gap  tsunami
# 0        7.0   14.000   768  17.0        1
# 1        6.9   25.000   735  34.0        0
# 2        7.0  579.000   755  18.0        1
# 3        7.3   37.000   833  21.0        1
# 4        6.6  624.464   670  27.0        1
# 5        7.0  660.000   755  26.0        1
# 6        6.8  630.379   711  22.0        1
# 7        6.7   20.000   797  37.0        1
# 8        6.8   20.000  1179  92.0        1
# 9        7.6   26.943  1799  69.0        1

# %%
#con el filtrado ya no existen datos faltantes
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   magnitude  782 non-null    float64
#  1   depth      782 non-null    float64
#  2   sig        782 non-null    int64
#  3   gap        782 non-null    float64
#  4   tsunami    782 non-null    int64
# dtypes: float64(3), int64(2)
# memory usage: 30.7 KB

# %%
df_filtrado.duplicated().sum()
#Hay 5 filas duplicadas que se van a eliminar
# Out:
# 5

# %%
df_filtrado = df_filtrado.drop_duplicates()

# %%
df_filtrado.duplicated().sum()
#ya no hay filas duplicadas
# Out:
# 0
